# %% [markdown]
# ## Data Acquisition

# %%
import pandas as pd
from sqlalchemy import create_engine

## DATA STORAGE AND MODELING
# Replace with your MySQL credentials
username = 'root'
password = 'Samoxshamas'
database = 'movies_db'
host = 'localhost'

# Create connection
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}/{database}')

# %%
from tmdbv3api import TMDb, Movie
import pandas as pd

# Set up TMDb
tmdb = TMDb()
tmdb.api_key = 'YOUR_API_KEY'  # replace with your key
tmdb.language = 'en'

# Initialize Movie API
tmdb_movie = Movie()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tmdbv3api import TMDb, Movie
#       2 import pandas as pd
#       4 # Set up TMDb
#
# ModuleNotFoundError: No module named 'tmdbv3api'

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (2025.11.12)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tmdbv3api import TMDb, Movie
import pandas as pd

# Set up TMDb
tmdb = TMDb()
tmdb.api_key = '45e798874d6c74f0c90bec91a7ed6d69'  # replace with your key
tmdb.language = 'en'

# Initialize Movie API
tmdb_movie = Movie()

# %%
# Fetch first 50 popular movies
# TMDb returns 20 movies per page
# ---------------------------
def fetch_movies(n=50):
    movies = []
    page = 1
    while len(movies) < n:
        page_movies = list(tmdb_movie.popular(page=page))  # convert AsObj to list
        movies.extend(page_movies)
        page += 1
    return movies[:n]

movies_list = fetch_movies(50)

# ---------------------------
# Convert to pandas DataFrame
# ---------------------------
data = []
for m in movies_list:
    data.append({
        'title': m.title,
        'release_year': int(m.release_date.split('-')[0]) if m.release_date else None,
        'genre': None,        # optional: can enrich later
        'director': None,     # optional
        'main_cast': None,    # optional
        'imdb_rating': None,  # optional
        'tmdb_rating': m.vote_average
    })

df_movies = pd.DataFrame(data)

# Preview
df_movies.head()
# Out:
#                title  release_year genre director main_cast imdb_rating  \
# 0  The Shadow's Edge          2025  None     None      None        None
# 1         Bureau 749          2024  None     None      None        None
# 2  The Family Plan 2          2025  None     None      None        None
# 3            Altered          2025  None     None      None        None
# 4       Frankenstein          2025  None     None      None        None
#
#    tmdb_rating
# 0        6.436
# 1        5.500
# 2        6.805
# 3        6.800
# 4        7.800

# %% [raw]
# # Now let’s move on and Load the Box Office dataset and integrate it with your MySQL database

# %%
import pandas as pd

# Load the top 1000 Box Office Mojo movies
df_box = pd.read_csv('boxofficemojoustop1000.tsv', sep='\t')

# Preview columns
print(df_box.columns)
print(df_box.head())

# Rename columns to match MySQL
df_box.rename(columns={
    'Title': 'title',                  # Movie title
    'Budget': 'budget',                # If exists
    'Domestic': 'domestic_revenue',    
    'International': 'international_revenue',
    'Worldwide': 'total_revenue'
}, inplace=True)

# Normalize titles for matching
df_box['title_norm'] = df_box['title'].str.lower().str.strip()

df_box.head()
# Out:
# Index(['Rank', 'Movie', 'Lifetime Gross', 'Year'], dtype='object')
#    Rank                                       Movie  Lifetime Gross  Year
# 0     1  Star Wars: Episode VII - The Force Awakens       936662225  2015
# 1     2                           Avengers: Endgame       858373000  2019
# 2     3                     Spider-Man: No Way Home       772170405  2021
# 3     4                                      Avatar       760507625  2009
# 4     5                               Black Panther       700426566  2018
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 20
#      11 df_box.rename(columns={
#      12     'Title': 'title',                  # Movie title
#      13     'Budget': 'budget',                # If exists
#    (...)     16     'Worldwide': 'total_revenue'
#      17 }, inplace=True)
#      19 # Normalize titles for matching
# ---> 20 df_box['title_norm'] = df_box['title'].str.lower().str.strip()
#      22 df_box.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'title'

# %%
# lets check for the column names before 

# See the exact column names
print(df_box.columns.tolist())
# Out:
# ['Rank', 'Movie', 'Lifetime Gross', 'Year']

# %%
# we need to adapt code to these column names.


# Load TSV
df_box = pd.read_csv('boxofficemojoustop1000.tsv', sep='\t')

# Strip spaces in column names just in case
df_box.columns = df_box.columns.str.strip()

# Rename columns
df_box.rename(columns={
    'Movie': 'title',
    'Lifetime Gross': 'total_revenue',
    'Year': 'release_year'
}, inplace=True)

# Optional: normalize title for matching
df_box['title_norm'] = df_box['title'].str.lower().str.strip()

# Convert revenue to numeric (remove $ and commas) using raw string
df_box['total_revenue'] = df_box['total_revenue'].replace(r'[\$,]', '', regex=True).astype(float)

# Preview
df_box.head()
# Out:
#    Rank                                       title  total_revenue  \
# 0     1  Star Wars: Episode VII - The Force Awakens    936662225.0
# 1     2                           Avengers: Endgame    858373000.0
# 2     3                     Spider-Man: No Way Home    772170405.0
# 3     4                                      Avatar    760507625.0
# 4     5                               Black Panther    700426566.0
#
#    release_year                                  title_norm
# 0          2015  star wars: episode vii - the force awakens
# 1          2019                           avengers: endgame
# 2          2021                     spider-man: no way home
# 3          2009                                      avatar
# 4          2018                               black panther

# %%
#Now assuming our TMDb DataFrame (df_movies) has title and release_year:
# Normalize TMDb titles
df_movies['title_norm'] = df_movies['title'].str.lower().str.strip()

# Merge datasets on title (and optionally year)
df_merged = pd.merge(df_movies, df_box, on='title_norm', how='inner', suffixes=('_tmdb','_box'))

print("Total TMDb movies:", len(df_movies))
print("Total Box Office movies:", len(df_box))
print("Matched movies:", len(df_merged))

# Show sample unmatched movies from Box Office
box_not_in_tmdb = df_box[~df_box['title_norm'].isin(df_movies['title_norm'])]
print(box_not_in_tmdb.head(20))
# Out:
# Total TMDb movies: 50
# Total Box Office movies: 1000
# Matched movies: 2
#     Rank                                          title  total_revenue  \
# 0      1     Star Wars: Episode VII - The Force Awakens    936662225.0
# 1      2                              Avengers: Endgame    858373000.0
# 2      3                        Spider-Man: No Way Home    772170405.0
# 3      4                                         Avatar    760507625.0
# 4      5                                  Black Panther    700426566.0
# 5      6                         Avengers: Infinity War    678815482.0
# 6      7                                        Titanic    659363944.0
# 7      8                                 Jurassic World    652385625.0
# 8      9                                   The Avengers    623357910.0
# 9     10        Star Wars: Episode VIII - The Last Jedi    620181382.0
# 10    11                                  Incredibles 2    608581744.0
# 11    12                                  The Lion King    543638043.0
# 12    13                                The Dark Knight    534858444.0
# 13    14                   Rogue One: A Star Wars Story    532177324.0
# 14    15  Star Wars: Episode IX - The Rise of Skywalker    515202542.0
# 15    16                           Beauty and the Beast    504481165.0
# 16    17                                   Finding Dory    486295561.0
# 17    18                                      Frozen II    477373578.0
# 18    19      Star Wars: Episode I - The Phantom Menace    474544677.0
# 19    20             Star Wars: Episode IV - A New Hope    460998507.0
#
#     release_year                                     title_norm
# 0           2015     star wars: episode vii - the force awakens
# 1           2019                              avengers: endgame
# 2           2021                        spider-man: no way home
# 3           2009                                         avatar
# 4           2018                                  black panther
# 5           2018                         avengers: infinity war
# 6           1997                                        titanic
# 7           2015                                 jurassic world
# 8           2012                                   the avengers
# 9           2017        star wars: episode viii - the last jedi
# 10          2018                                  incredibles 2
# 11          2019                                  the lion king
# 12          2008                                the dark knight
# 13          2016                   rogue one: a star wars story
# 14          2019  star wars: episode ix - the rise of skywalker
# 15          2017                           beauty and the beast
# 16          2016                                   finding dory
# 17          2019                                      frozen ii
# 18          1999      star wars: episode i - the phantom menace
# 19          1977             star wars: episode iv - a new hope

# %%
#MATCHES ARE SO LOW SO ITS BETTER IF WE JUST CHANGE THE DATASET TO ANOTHER ONE

# %%
df_box = pd.read_csv('Top_1000_Highest_Grossing_Movies_Of_All_Time.csv')  

# Inspect columns
print(df_box.columns)
df_box.head()
# Out:
# Index(['Movie Title', 'Year of Realease', 'Genre', 'Movie Rating', 'Duration',
#        'Gross', 'Worldwide LT Gross', 'Metascore', 'Votes', 'Logline'],
#       dtype='object')
#                                   Movie Title Year of Realease  \
# 0                                      Avatar             2009
# 1                           Avengers: Endgame             2019
# 2                                     Titanic             1997
# 3  Star Wars: Episode VII - The Force Awakens             2015
# 4                      Avengers: Infinity War             2018
#
#                       Genre  Movie Rating  Duration     Gross  \
# 0  Action,Adventure,Fantasy           7.8       162  $760.51M
# 1    Action,Adventure,Drama           8.4       181  $858.37M
# 2             Drama,Romance           7.9       194  $659.33M
# 3   Action,Adventure,Sci-Fi           7.8       138  $936.66M
# 4   Action,Adventure,Sci-Fi           8.4       149  $678.82M
#
#   Worldwide LT Gross Metascore      Votes  \
# 0     $2,847,397,339        83  1,236,962
# 1     $2,797,501,328        78  1,108,641
# 2     $2,201,647,264        75  1,162,142
# 3     $2,069,521,700        80    925,551
# 4     $2,048,359,754        68  1,062,517
#
#                                              Logline
# 0  A paraplegic Marine dispatched to the moon Pan...
# 1  After the devastating events of Avengers: Infi...
# 2  A seventeen-year-old aristocrat falls in love ...
# 3  As a new threat to the galaxy rises, Rey, a de...
# 4  The Avengers and their allies must be willing ...

# %% [markdown]
# ## Data Integration / Enrichment
#
# Integration: Merged Box Office dataset with TMDb metadata using title_norm
#
# Enrichment: Added TMDb ratings, genres, etc., to the Box Office dataset
#
# Matches: 932 / 1000 movies matched

# %%
# Normalize titles for matching
df_box['title_norm'] = df_box['Movie Title'].str.lower().str.strip()

# Optional: convert revenue to numeric (remove $ and commas)
df_box['Worldwide LT Gross'] = df_box['Worldwide LT Gross'].replace(r'[\$,]', '', regex=True).astype(float)

# Preview
df_box[['Movie Title', 'Year of Realease', 'Worldwide LT Gross', 'title_norm']].head()
# Out:
#                                   Movie Title Year of Realease  \
# 0                                      Avatar             2009
# 1                           Avengers: Endgame             2019
# 2                                     Titanic             1997
# 3  Star Wars: Episode VII - The Force Awakens             2015
# 4                      Avengers: Infinity War             2018
#
#    Worldwide LT Gross                                  title_norm
# 0        2.847397e+09                                      avatar
# 1        2.797501e+09                           avengers: endgame
# 2        2.201647e+09                                     titanic
# 3        2.069522e+09  star wars: episode vii - the force awakens
# 4        2.048360e+09                      avengers: infinity war

# %%
#Also normalize tmdb titles: 

# Assuming df_tmdb is your metadata DataFrame
df_tmdb['title_norm'] = df_tmdb['title'].str.lower().str.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 #Also normalize tmdb titles:
#       2
#       3 # Assuming df_tmdb is your metadata DataFrame
# ----> 4 df_tmdb['title_norm'] = df_tmdb['title'].str.lower().str.strip()
#
# NameError: name 'df_tmdb' is not defined

# %%
tmdb_movies_list = []
for title in df_box['Movie Title']:
    try:
        results = tmdb_movie.search(title)
        if results:
            m = results[0]  # take the first result
            tmdb_movies_list.append({
                'title': m.title,
                'release_year': int(m.release_date.split('-')[0]) if m.release_date else None,
                'genre': None,
                'director': None,
                'main_cast': None,
                'imdb_rating': None,
                'tmdb_rating': m.vote_average,
                'title_norm': m.title.lower().strip()
            })
    except:
        continue

df_tmdb = pd.DataFrame(tmdb_movies_list)
print("TMDb metadata fetched:", len(df_tmdb))
# Out:
# TMDb metadata fetched: 983

# %%
# Now again Assuming df_tmdb is your metadata DataFrame
df_tmdb['title_norm'] = df_tmdb['title'].str.lower().str.strip()

# %%
# Merge on normalized title
df_matches = pd.merge(df_tmdb, df_box, on='title_norm', how='inner', suffixes=('_tmdb','_box'))

print("Total TMDb movies fetched:", len(df_tmdb))
print("Total Box Office movies:", len(df_box))
print("Number of matches found:", len(df_matches))

# Preview matched entries
df_matches[['title', 'Movie Title', 'release_year', 'Year of Realease', 'Worldwide LT Gross']].head(10)
# Out:
# Total TMDb movies fetched: 983
# Total Box Office movies: 1000
# Number of matches found: 933
#                      title              Movie Title  release_year  \
# 0                   Avatar                   Avatar        2009.0
# 1        Avengers: Endgame        Avengers: Endgame        2019.0
# 2                  Titanic                  Titanic        1997.0
# 3   Avengers: Infinity War   Avengers: Infinity War        2018.0
# 4  Spider-Man: No Way Home  Spider-Man: No Way Home        2021.0
# 5           Jurassic World           Jurassic World        2015.0
# 6            The Lion King            The Lion King        1994.0
# 7            The Lion King            The Lion King        1994.0
# 8             The Avengers             The Avengers        2012.0
# 9                Frozen II                Frozen II        2019.0
#
#   Year of Realease  Worldwide LT Gross
# 0             2009        2.847397e+09
# 1             2019        2.797501e+09
# 2             1997        2.201647e+09
# 3             2018        2.048360e+09
# 4             2021        1.911433e+09
# 5             2015        1.671537e+09
# 6             2019        1.663250e+09
# 7             1994        1.063612e+09
# 8             2012        1.518816e+09
# 9             2019        1.450027e+09

# %% [raw]
# Veryyyy Perfect...that’s excellent coverage!
#
# 932 matches out of 1000 is a very high overlap.
#
# Only 68 Box Office movies are missing from TMDb, which is manageable.
#
# This means your dataset is now ready for integration and further processing.

# %% [raw]
# THIS STep is within the data storage and modeling:

# %%
# Insert df_final into MySQL table named 'movies'
df_final.to_sql('movies', con=engine, if_exists='replace', index=False)
print("Data inserted into MySQL successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Insert df_final into MySQL table named 'movies'
# ----> 2 df_final.to_sql('movies', con=engine, if_exists='replace', index=False)
#       3 print("Data inserted into MySQL successfully!")
#
# NameError: name 'df_final' is not defined

# %%
# Keep only relevant columns
df_final = df_matches[[
    'title', 'release_year', 'genre', 'director', 'main_cast',
    'imdb_rating', 'tmdb_rating', 'Movie Rating', 'Duration',
    'Worldwide LT Gross', 'Metascore', 'Votes', 'Logline'
]]

# Rename columns for clarity
df_final.rename(columns={
    'Movie Rating': 'mpaa_rating',
    'Duration': 'duration_minutes'
}, inplace=True)

df_final.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8300\2357730397.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.rename(columns={
#                      title  release_year genre director main_cast imdb_rating  \
# 0                   Avatar        2009.0  None     None      None        None
# 1        Avengers: Endgame        2019.0  None     None      None        None
# 2                  Titanic        1997.0  None     None      None        None
# 3   Avengers: Infinity War        2018.0  None     None      None        None
# 4  Spider-Man: No Way Home        2021.0  None     None      None        None
#
#    tmdb_rating  mpaa_rating  duration_minutes  Worldwide LT Gross Metascore  \
# 0        7.594          7.8               162        2.847397e+09        83
# 1        8.237          8.4               181        2.797501e+09        78
# 2        7.903          7.9               194        2.201647e+09        75
# 3        8.235          8.4               149        2.048360e+09        68
# 4        7.900          8.3               148        1.911433e+09        71
#
#        Votes                                            Logline
# 0  1,236,962  A paraplegic Marine dispatched to the moon Pan...
# 1  1,108,641  After the devastating events of Avengers: Infi...
# 2  1,162,142  A seventeen-year-old aristocrat falls in love ...
# 3  1,062,517  The Avengers and their allies must be willing ...
# 4    735,006  With Spider-Man's identity now revealed, Peter...

# %%
# Insert table
df_final.to_sql('movies', con=engine, if_exists='replace', index=False)
print("Data inserted into MySQL successfully!")
# Out:
# Data inserted into MySQL successfully!

# %%
#Lets verify the merge and the data quality


print("Total TMDb movies:", len(df_tmdb))
print("Total Box Office movies:", len(df_box))
print("Total merged movies (df_final):", len(df_final))
# Out:
# Total TMDb movies: 983
# Total Box Office movies: 1000
# Total merged movies (df_final): 932

# %% [markdown]
# ## Data Profiling / Quality Check

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# For plots to appear inline in Jupyter
# %matplotlib inline

# %%
#DataSet shape:
print(df_final.shape)
# Out:
# (932, 13)

# %%
#Check for the missing values: (which columns have missing entries)
print(df_final.isnull().sum())
# Out:
# title                   0
# release_year            1
# genre                 932
# director              932
# main_cast             932
# imdb_rating           932
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %% [raw]
# For now we can work with these missing values, and maybe enrich columns in the future.. And maybe later for Optional enrichment: genre,director, main_cast, imdb_rating

# %%
# Now lets check for duplicates: 

duplicates = df_final[df_final.duplicated(subset=['title', 'release_year'], keep=False)]
print("\nNumber of duplicate movies:", len(duplicates))
if len(duplicates) > 0:
    print(duplicates[['title', 'release_year']].head(10))
# Out:
# Number of duplicate movies: 48
#                    title  release_year
# 5          The Lion King        1994.0
# 6          The Lion King        1994.0
# 15  Beauty and the Beast        1991.0
# 16  Beauty and the Beast        1991.0
# 34         The Lion King        1994.0
# 35         The Lion King        1994.0
# 36               Aladdin        2019.0
# 37               Aladdin        2019.0
# 49       The Jungle Book        1967.0
# 50       The Jungle Book        1967.0

# %%
# Best i could do is to keep the first occurence of the repeated movie:

# Remove duplicates based on title + release_year, keep the first occurrence
df_final = df_final.drop_duplicates(subset=['title', 'release_year'], keep='first')

# Verify duplicates are gone
duplicates = df_final[df_final.duplicated(subset=['title', 'release_year'], keep=False)]
print("Number of duplicate movies after cleaning:", len(duplicates))
print("Dataset shape after removing duplicates:", df_final.shape)
# Out:
# Number of duplicate movies after cleaning: 0
# Dataset shape after removing duplicates: (897, 13)

# %%
# Some categorical distr: 


# Most frequent genres
print("\nTop 10 genres:")
print(df_final['genre'].value_counts().head(10))

##this will give us zero bc the genre column is not enriched.
# Out:
# Top 10 genres:
# Series([], Name: count, dtype: int64)

# %%
#TOP 3 movies by tmdb: 

# Sort the dataset by 'tmdb_rating' in descending order
# This will put the highest rated movies at the top
top10_tmdb = df_final.sort_values(by='tmdb_rating', ascending=False)

# Select only the columns we want to display
top10_tmdb = top10_tmdb[['title', 'release_year', 'tmdb_rating', 'Worldwide LT Gross']]

# Take the top 10
top10_tmdb = top10_tmdb.head(3)

# Display the top 10 movies
print("Top 10 Movies by TMDb Rating:")
print(top10_tmdb)
# Out:
# Top 10 Movies by TMDb Rating:
#                 title  release_year  tmdb_rating  Worldwide LT Gross
# 612     The Godfather        1972.0        8.684        2.503418e+08
# 441  Schindler's List        1993.0        8.566        3.221612e+08
# 45    The Dark Knight        2008.0        8.524        1.006102e+09

# %% [markdown]
# ## Data Analysis

# %%
# Check basic stats for numeric columns: ratings, gross, votes, duration
numeric_cols = [
    'release_year',
    'tmdb_rating',
    'imdb_rating',
    'Worldwide LT Gross',
    'Metascore',
    'Votes',
    'duration_minutes'
]

print("\nNumeric summary statistics:")
print(df_final[numeric_cols].describe())
# Out:
# Numeric summary statistics:
#        release_year  tmdb_rating  imdb_rating  Worldwide LT Gross   Metascore  \
# count    896.000000   897.000000          0.0        8.970000e+02  895.000000
# mean    2006.699777     6.787983          NaN        4.099548e+08   59.277095
# std       11.372231     0.884805          NaN        2.892350e+08   15.996269
# min     1938.000000     0.000000          NaN        1.766002e+08   12.000000
# 25%     2001.000000     6.300000          NaN        2.251321e+08   48.000000
# 50%     2009.000000     6.800000          NaN        3.113126e+08   59.000000
# 75%     2015.000000     7.314000          NaN        4.741718e+08   71.000000
# max     2026.000000     8.684000          NaN        2.847397e+09  100.000000
#
#        Votes  duration_minutes
# count    0.0        897.000000
# mean     NaN        117.585284
# std      NaN         21.851358
# min      NaN         69.000000
# 25%      NaN        101.000000
# 50%      NaN        116.000000
# 75%      NaN        130.000000
# max      NaN        238.000000

# %%
#Plot Distribution of TMDb Ratings

# Set plot style
sns.set(style="whitegrid")

plt.figure(figsize=(12,6))

# Plot a histogram with KDE (smooth curve)
sns.histplot(df_final['tmdb_rating'], bins=20, kde=True, color='skyblue')

# Add labels and title
plt.title("Distribution of TMDb Ratings for All Movies", fontsize=16)
plt.xlabel("TMDb Rating", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)

# Show plot
plt.show()

# %%
# Plot Distribution of Worldwide Gross

plt.figure(figsize=(12,6))

# Use log scale on x-axis because revenue varies widely
sns.histplot(df_final['Worldwide LT Gross'], bins=30, kde=True, color='orange', log_scale=(True, False))

# Add labels and title
plt.title("Distribution of Worldwide Gross Revenue", fontsize=16)
plt.xlabel("Worldwide Gross Revenue (log scale)", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)

plt.show()

# %%
#Dist of meta score


plt.figure(figsize=(10,5))
plt.hist(df_final['Metascore'].dropna(), bins=30)
plt.title('Distribution of Metascore')
plt.xlabel('Metascore')
plt.ylabel('Count')
plt.show()

# %%
# Correlation analysis

# How numeric columns relate to each other
corr = df_final[numeric_cols].corr()
print("\nCorrelation matrix:\n", corr)

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numeric Columns")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       1 # Correlation analysis
#       2
#       3 # How numeric columns relate to each other
# ----> 4 corr = df_final[numeric_cols].corr()
#       5 print("\nCorrelation matrix:\n", corr)
#       7 plt.figure(figsize=(10,8))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '******'

# %%
# lets identify numeric problems: 

numeric_cols = ['tmdb_rating', 'imdb_rating', 'Worldwide LT Gross', 'Metascore', 'Votes', 'duration_minutes']

# Check unique values for each column to spot non-numeric entries
for col in numeric_cols:
    print(f"Unique values in {col}:")
    print(df_final[col].unique()[:20])  # print first 20 unique values
    print("----------")
# Out:
# Unique values in tmdb_rating:
# [7.594 8.237 7.903 8.235 7.9   8.255 7.859 7.2   8.164 7.3   7.366 8.1
#  6.5   7.7   7.5   6.9   6.4   7.448 6.871 8.49 ]
# ----------
# Unique values in imdb_rating:
# [None]
# ----------
# Unique values in Worldwide LT Gross:
# [2.84739734e+09 2.79750133e+09 2.20164726e+09 2.04835975e+09
#  1.91143255e+09 1.66325049e+09 1.51881552e+09 1.45002693e+09
#  1.44073974e+09 1.40280954e+09 1.34759797e+09 1.34235994e+09
#  1.31046630e+09 1.28150810e+09 1.27357622e+09 1.24308924e+09
#  1.23600512e+09 1.15944466e+09 1.15333750e+09 1.14852839e+09]
# ----------
# Unique values in Metascore:
# ['83' '78' '75' '68' '71' '55' '69' '64' '66' '88' '85' '51' '65' '80'
#  '56' '94' '42' '81' '32' '59']
# ----------
# Unique values in Votes:
# ['1,236,962' '1,108,641' '1,162,142' '1,062,517' '735,006' '244,170'
#  '1,381,149' '171,270' '400,255' '856,080' '751,667' '867,676' '315,318'
#  '621,680' '308,027' '295,100' '231,745' '238,820' '779,525' '469,031']
# ----------
# Unique values in duration_minutes:
# [162 181 194 149 148 118 143 103 130 141 134 128 102 129 136  91 147 201
#  123 154]
# ----------

# %%
# Lets clean and convert to numeric, replace invalid entries ('******', empty strings, etc.) with NaN

for col in numeric_cols:
    df_final[col] = pd.to_numeric(df_final[col], errors='coerce')  # invalid parsing becomes NaN

# Check missing values after cleaning
print(df_final[numeric_cols].isnull().sum())
# Out:
# tmdb_rating             0
# imdb_rating           897
# Worldwide LT Gross      0
# Metascore               2
# Votes                 897
# duration_minutes        0
# dtype: int64

# %%
# Compute correlation matrix using only numeric columns
corr_matrix = df_final[numeric_cols].corr()

# Display
print(corr_matrix)

# Optional: plot heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
#                     tmdb_rating  imdb_rating  Worldwide LT Gross  Metascore  \
# tmdb_rating            1.000000          NaN            0.250494   0.541119
# imdb_rating                 NaN          NaN                 NaN        NaN
# Worldwide LT Gross     0.250494          NaN            1.000000   0.215348
# Metascore              0.541119          NaN            0.215348   1.000000
# Votes                       NaN          NaN                 NaN        NaN
# duration_minutes       0.324435          NaN            0.283602   0.266289
#
#                     Votes  duration_minutes
# tmdb_rating           NaN          0.324435
# imdb_rating           NaN               NaN
# Worldwide LT Gross    NaN          0.283602
# Metascore             NaN          0.266289
# Votes                 NaN               NaN
# duration_minutes      NaN          1.000000

# %%
#top10_gross = df_final.nlargest(10, 'Worldwide LT Gross')[['title', 'release_year', 'Worldwide LT Gross']]


top10_gross = df_final.nlargest(10, 'Worldwide LT Gross')[['title', 'release_year', 'Worldwide LT Gross']]
print("Top 10 Movies by Worldwide Box Office Gross:")
print(top10_gross)
# Out:
# Top 10 Movies by Worldwide Box Office Gross:
#                       title  release_year  Worldwide LT Gross
# 0                    Avatar        2009.0        2.847397e+09
# 1         Avengers: Endgame        2019.0        2.797501e+09
# 2                   Titanic        1997.0        2.201647e+09
# 3    Avengers: Infinity War        2018.0        2.048360e+09
# 4   Spider-Man: No Way Home        2021.0        1.911433e+09
# 5             The Lion King        1994.0        1.663250e+09
# 7              The Avengers        2012.0        1.518816e+09
# 8                 Frozen II        2019.0        1.450027e+09
# 9         Top Gun: Maverick        2022.0        1.440740e+09
# 10  Avengers: Age of Ultron        2015.0        1.402810e+09

# %%
#Top 5 Movies by TMDb Rating

top5_tmdb = df_final.nlargest(5, 'tmdb_rating')[['title', 'release_year', 'tmdb_rating']]
print("\nTop 5 Movies by TMDb Rating:")
print(top10_tmdb)
# Out:
# Top 5 Movies by TMDb Rating:
#                 title  release_year  tmdb_rating
# 612     The Godfather        1972.0        8.684
# 441  Schindler's List        1993.0        8.566
# 45    The Dark Knight        2008.0        8.524
# 528    The Green Mile        1999.0        8.503
# 125      Interstellar        2014.0        8.500

# %%
#Top 10 Movies by IMDb Rating

top5_imdb = df_final.nlargest(5, 'imdb_rating')[['title', 'release_year', 'imdb_rating']]
print("\nTop 5 Movies by IMDb Rating:")
print(top10_imdb)
# Out:
# Top 5 Movies by IMDb Rating:
#                      title  release_year  imdb_rating
# 0                   Avatar        2009.0          NaN
# 1        Avengers: Endgame        2019.0          NaN
# 2                  Titanic        1997.0          NaN
# 3   Avengers: Infinity War        2018.0          NaN
# 4  Spider-Man: No Way Home        2021.0          NaN

# %%
#Top 5 Movies by Votes

top5_votes = df_final.nlargest(5, 'Votes')[['title', 'release_year', 'Votes']]
print("\nTop 5 Movies by Number of Votes:")
print(top5_votes)
# Out:
# Top 5 Movies by Number of Votes:
#                      title  release_year  Votes
# 0                   Avatar        2009.0    NaN
# 1        Avengers: Endgame        2019.0    NaN
# 2                  Titanic        1997.0    NaN
# 3   Avengers: Infinity War        2018.0    NaN
# 4  Spider-Man: No Way Home        2021.0    NaN

# %%
#Top 10 Movies by Metascore (Shows critical acclaim)

top10_meta = df_final.nlargest(10, 'Metascore')[['title', 'release_year', 'Metascore']]
print("\nTop 10 Movies by Metascore:")
print(top10_meta)
# Out:
# Top 10 Movies by Metascore:
#                                              title  release_year  Metascore
# 612                                  The Godfather        1972.0      100.0
# 308                             Gone with the Wind        1939.0       97.0
# 117                                        Gravity        2013.0       96.0
# 152                                    Ratatouille        2007.0       96.0
# 857                               12 Years a Slave        2013.0       96.0
# 205                                         WALL·E        2008.0       95.0
# 317                                      Toy Story        1995.0       95.0
# 700                             The Social Network        2010.0       95.0
# 873                Snow White and the Seven Dwarfs        1938.0       95.0
# 22   The Lord of the Rings: The Return of the King        2003.0       94.0

# %% [markdown]
# ## DATA QUALITY IMPROVEMENT / FINAL CLEANING

# %%
#lets reshow any missing values and maybe handle some. 

# Summary of missing values in each column
df_final.isnull().sum()
# Out:
# title                   0
# release_year            1
# genre                 933
# director              933
# main_cast             933
# imdb_rating           933
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %%
#Release year has one missing value lets drop it (for now ill leave the others)

# Drop rows with missing release year
df_final = df_final.dropna(subset=['release_year'])

# %%
#Recheck

df_final.isnull().sum()
# Out:
# title                   0
# release_year            0
# genre                 932
# director              932
# main_cast             932
# imdb_rating           932
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %%
# Show duplicate movies before removal

dups = df_final[df_final.duplicated(subset=['title', 'release_year'], keep=False)]

print("Number of duplicate rows:", len(dups))
dups[['title', 'release_year', 'Worldwide LT Gross', 'imdb_rating', 'tmdb_rating']].head(20)
# Out:
# Number of duplicate rows: 48
#                                   title  release_year  Worldwide LT Gross  \
# 6                         The Lion King        1994.0        1.663250e+09
# 7                         The Lion King        1994.0        1.063612e+09
# 16                 Beauty and the Beast        1991.0        1.273576e+09
# 17                 Beauty and the Beast        1991.0        4.249676e+08
# 35                        The Lion King        1994.0        1.663250e+09
# 36                        The Lion King        1994.0        1.063612e+09
# 37                              Aladdin        2019.0        1.050694e+09
# 38                              Aladdin        2019.0        5.040502e+08
# 50                      The Jungle Book        1967.0        9.665549e+08
# 51                      The Jungle Book        1967.0        2.058436e+08
# 186                   X-Men: Apocalypse        2016.0        5.439341e+08
# 187  Sherlock Holmes: A Game of Shadows        2011.0        5.438484e+08
# 201                            Godzilla        1998.0        5.249761e+08
# 202                            Godzilla        1998.0        3.790143e+08
# 204  Sherlock Holmes: A Game of Shadows        2011.0        5.438484e+08
# 213                             Aladdin        2019.0        1.050694e+09
# 214                             Aladdin        2019.0        5.040502e+08
# 227        Teenage Mutant Ninja Turtles        2014.0        4.850048e+08
# 228        Teenage Mutant Ninja Turtles        2014.0        2.020848e+08
# 282                Beauty and the Beast        1991.0        1.273576e+09
#
#     imdb_rating  tmdb_rating
# 6          None        8.255
# 7          None        8.255
# 16         None        7.700
# 17         None        7.700
# 35         None        8.255
# 36         None        8.255
# 37         None        7.093
# 38         None        7.093
# 50         None        7.300
# 51         None        7.300
# 186        None        6.518
# 187        None        7.141
# 201        None        5.600
# 202        None        5.600
# 204        None        7.141
# 213        None        7.093
# 214        None        7.093
# 227        None        5.900
# 228        None        5.900
# 282        None        7.700

# %%
#Lets remove those 48

df_final = df_final.drop_duplicates(subset=['title', 'release_year'])

# %%
#Check


dups = df_final[df_final.duplicated(subset=['title', 'release_year'], keep=False)]

print("Number of duplicate rows:", len(dups))
# Out:
# Number of duplicate rows: 0

# %%
#Lets also handle some outliers (in duration)

# Choose a column (example: duration)
col = 'duration_minutes'

Q1 = df_final[col].quantile(0.25)
Q3 = df_final[col].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_final[(df_final[col] < lower_bound) | (df_final[col] > upper_bound)]

print("Number of outliers:", len(outliers))
outliers[[col, 'title', 'release_year']].head(20)
# Out:
# Number of outliers: 16
#      duration_minutes                                              title  \
# 1                 181                                  Avengers: Endgame
# 2                 194                                            Titanic
# 23                201      The Lord of the Rings: The Return of the King
# 57                179              The Lord of the Rings: The Two Towers
# 63                178  The Lord of the Rings: The Fellowship of the Ring
# 102               176                                         The Batman
# 179               187                                          King Kong
# 257               183                                       Pearl Harbor
# 284               181                                 Dances with Wolves
# 309               238                                 Gone with the Wind
# 320               180                            The Wolf of Wall Street
# 442               195                                   Schindler's List
# 529               189                                     The Green Mile
# 613               175                                      The Godfather
# 753               178                                         Braveheart
# 788               189                                                JFK
#
#      release_year
# 1          2019.0
# 2          1997.0
# 23         2003.0
# 57         2002.0
# 63         2001.0
# 102        2022.0
# 179        2005.0
# 257        2001.0
# 284        1990.0
# 309        1939.0
# 320        2013.0
# 442        1993.0
# 529        1999.0
# 613        1972.0
# 753        1995.0
# 788        1991.0

# %% [raw]
# Those arent outliers.
# Very Good.
# We got 16 outliers cause Movies longer than upper threshold are flagged automatically. But some genres (epic, historical, drama) are genuinely long
#
# A bad outlier looks like:
#
# 0 minutes
#
# 900 minutes
#
# -10 minutes
#
# 10,000 minutes
#
# Blank / missing values
#
# But your flagged values are simply unusually long but valid movies.

# %%
#LEts go back and handle the other missing values: 


df_final.isnull().sum()
# Out:
# title                   0
# release_year            0
# genre                 897
# director              897
# main_cast             897
# imdb_rating           897
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %%
#Ok for the imdb rating, TMDB movies don't have IMDB rating so i'll fill with mean IMDB rating. This keeps the dataset balanced

df_final['imdb_rating'] = df_final['imdb_rating'].fillna(df_final['imdb_rating'].mean())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8300\2028850567.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final['imdb_rating'] = df_final['imdb_rating'].fillna(df_final['imdb_rating'].mean())

# %%
#I'll converrt the column into numeric before filling (tho this is not an error)

df_final['imdb_rating'] = pd.to_numeric(df_final['imdb_rating'], errors='coerce')
df_final['imdb_rating'] = df_final['imdb_rating'].fillna(df_final['imdb_rating'].mean())

# %%
#For all the categorical columns i'll just fill missing values with unknown.

df_final['genre'] = df_final['genre'].fillna('Unknown')
df_final['director'] = df_final['director'].fillna('Unknown')
df_final['main_cast'] = df_final['main_cast'].fillna('Unknown')

# %%
#RECHECK 

df_final.isnull().sum()
# Out:
# title                   0
# release_year            0
# genre                   0
# director                0
# main_cast               0
# imdb_rating           897
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %%
df_final['imdb_rating'] = pd.to_numeric(df_final['imdb_rating'], errors='coerce')

# %%
df_final['imdb_rating'] = df_final['imdb_rating'].fillna(df_final['imdb_rating'].mean())

# %%
df_final.isnull().sum()
# Out:
# title                   0
# release_year            0
# genre                   0
# director                0
# main_cast               0
# imdb_rating           897
# tmdb_rating             0
# mpaa_rating             0
# duration_minutes        0
# Worldwide LT Gross      0
# Metascore               0
# Votes                   0
# Logline                 0
# dtype: int64

# %%
#I guess there are weird characters thats why the rating isnt working: 

df_final['imdb_rating'] = (
    df_final['imdb_rating']
    .astype(str)
    .str.strip()
    .replace(['', 'N/A', 'NaN', 'nan', 'None', '****', '***', '**', '*'], pd.NA)
)

# %%
#AGain to numeric after stripping 

df_final['imdb_rating'] = pd.to_numeric(df_final['imdb_rating'], errors='coerce')

# %% [markdown]
# df_final['imdb_rating'] = df_final['imdb_rating'].fillna(df_final['imdb_rating'].mean())
# df_final['imdb_rating'].isnull().sum()

# %%
df_final['imdb_rating'].unique()
# Out:
# array([nan])

# %%
df_final['imdb_rating'].notna().sum()
# Out:
# np.int64(0)

# %%
#Now i see MDB ratings never existed in the dataset. Cause i created that column and and when merged from tmdb api and the csv there where no actual values 
#I'll just drop the whole column cause its not useful

df_final = df_final.drop(columns=['imdb_rating'])

# %%
df_final.isnull().sum()
# Out:
# title                 0
# release_year          0
# genre                 0
# director              0
# main_cast             0
# tmdb_rating           0
# mpaa_rating           0
# duration_minutes      0
# Worldwide LT Gross    0
# Metascore             0
# Votes                 0
# Logline               0
# dtype: int64

# %% [markdown]
# ## Kafka Section
#
# In our Data Management project, we have already processed and analyzed movie metadata and box office data from the `Top_1000_Highest_Grossing_Movies_Of_All_Time.csv` dataset.
#
# To demonstrate **real-time data streaming capabilities**, we integrate **Apache Kafka** into our workflow. Kafka is a distributed messaging system designed to handle **high-throughput, real-time data pipelines**. It allows data to flow from producers to consumers reliably and efficiently.

# %%
# !pip install kafka-python pandas
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaProducer
import pandas as pd
import json

# Connect to Kafka
producer = KafkaProducer(
    bootstrap_servers='localhost:9092',  # Kafka broker
    value_serializer=lambda v: json.dumps(v).encode('utf-8')  # convert dict to JSON string
)

# Load your CSV
csv_file = 'Top_1000_Highest_Grossing_Movies_Of_All_Time.csv'
df = pd.read_csv(csv_file)

# Send only first 50 rows for demonstration
for _, row in df.head(50).iterrows():
    producer.send('movie_topic', row.to_dict())

producer.flush()
print("First 50 rows sent to Kafka topic 'movie_topic'!")
# Out:
# First 50 rows sent to Kafka topic 'movie_topic'!

# %%
from kafka import KafkaConsumer
import json

# Connect to Kafka topic
consumer = KafkaConsumer(
    'movie_topic',
    bootstrap_servers='localhost:9092',
    value_deserializer=lambda m: json.loads(m.decode('utf-8'))
)

# Read first 10 messages for testing
print("Reading messages from Kafka:")
for i, message in enumerate(consumer):
    print(f"{i+1}: {message.value}")
    if i >= 9:  # stop after 10 messages
        break
